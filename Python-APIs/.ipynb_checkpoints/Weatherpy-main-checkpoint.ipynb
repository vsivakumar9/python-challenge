# %%
#import required python libs.
import requests
import json
from pprint import pprint
from citipy import citipy
import random
import pandas as pd
import openweathermapy.core as owm
#config
from config import api_key
print(api_key)
# Out:
# 105bc2c8a00675ea3a807f619fd5e9cc

# %%
#urlw for openweather
#url = "http://api.openweathermap.org/data/2.5/weather?"
cnt=0
latlist=list()
longlist=list()

for k in range(-180,181,20):
    longlist.append(k)
#longlist=[-180,-160,-140,-120,-100,-8-75,-50,0,50,75,100,150,175]

#list of cities
cityset=set()

#list of countries corresponding to the city.
cnylist=list()
#create list of longitudes for use as a random choice

for i in range(-90,90,+2):
#use latitude choice from -90 to +90 and get a city closest to that latitude.
    for j in longlist:
        lat=i
        long=j
        city = citipy.nearest_city(lat, long)
        cityset.add(city.city_name)
        cnylist.append(city.country_code)
print(str(len(cityset)))
print(str(len(cnylist)))
# Out:
# 555
# 1710

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
print(api_key)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=105bc2c8a00675ea3a807f619fd5e9cc&units=metric&q=
# 105bc2c8a00675ea3a807f619fd5e9cc

# %%
# Get current weather for all the cities using openweathermapy. 
#initialize count variables. 
cntcity=0
cntfail=0
     
# set up lists to hold reponse info
citylist=list()
cloudiness=list()
temp = list()
cnycode=list()
date=list()
humidity=list()
lat = list()
long=list()
tempmax=list()
windspeed=list()

# Loop through the list of cities and perform a request for data on each
for city in cityset:
    #print(str(city))
    cntcity=cntcity+1
    print("Retrieving  data for record " + str(cntcity) + " " + city)
    try:
        weatherdetails = requests.get(query_url + city).json()
        #pprint(weatherdetails)
        citylist.append (weatherdetails["name"])
        cloudiness.append (weatherdetails["clouds"]["all"])
        cnycode.append (weatherdetails["sys"]["country"])
        #datetime=weatherdetails["dt"]
        date.append (weatherdetails["dt"])
        humidity.append (weatherdetails["main"]["humidity"])
        lat.append (weatherdetails["coord"]["lat"])
        long.append (weatherdetails["coord"]["lon"])
        tempmax.append (weatherdetails["main"]["temp_max"])
        windspeed.append (weatherdetails["wind"]["speed"])
    except:
        cntfail +=1
        print("Error in getting data for city " + city)
        print("error code: " + weatherdetails["cod"])
        print("message: " + weatherdetails["message"])
        
print("Data Retrieval Complete....")
print("---------------------------------------------------------")
print("Num cities weather not found: " + str(cntfail))
# Out:
# Retrieving  data for record 0 uvalde
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 29.21, 'lon': -99.79},
#  'dt': 1529509860,
#  'id': 4738721,
#  'main': {'humidity': 88,
#           'pressure': 1011,
#           'temp': 26.08,
#           'temp_max': 27,
#           'temp_min': 25},
#  'name': 'Uvalde',
#  'sys': {'country': 'US',
#          'id': 2618,
#          'message': 0.0038,
#          'sunrise': 1529494828,
#          'sunset': 1529545284,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 4.1}}
# Retrieving  data for record 0 shimoda
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 34.7, 'lon': 138.93},
#  'dt': 1529508180,
#  'id': 1852357,
#  'main': {'humidity': 100,
#           'pressure': 998,
#           'temp': 21,
#           'temp_max': 21,
#           'temp_min': 21},
#  'name': 'Shimoda',
#  'sys': {'country': 'JP',
#          'id': 7573,
#          'message': 0.0033,
#          'sunrise': 1529436681,
#          'sunset': 1529488829,
#          'type': 1},
#  'visibility': 1000,
#  'weather': [{'description': 'heavy intensity shower rain',
#               'icon': '09n',
#               'id': 522,
#               'main': 'Rain'}],
#  'wind': {'speed': 1}}
# Retrieving  data for record 0 atuona
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1529511412,
#  'id': 4020109,
#  'main': {'grnd_level': 1026.37,
#           'humidity': 99,
#           'pressure': 1026.37,
#           'sea_level': 1026.41,
#           'temp': 27.19,
#           'temp_max': 27.19,
#           'temp_min': 27.19},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0055,
#          'sunrise': 1529508681,
#          'sunset': 1529550269},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 89.003, 'speed': 5.36}}
# Retrieving  data for record 0 pedernales
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 0.07, 'lon': -80.05},
#  'dt': 1529511412,
#  'id': 3653307,
#  'main': {'grnd_level': 998.41,
#           'humidity': 98,
#           'pressure': 998.41,
#           'sea_level': 1028.03,
#           'temp': 23.14,
#           'temp_max': 23.14,
#           'temp_min': 23.14},
#  'name': 'Pedernales',
#  'rain': {'3h': 0.575},
#  'sys': {'country': 'EC',
#          'message': 0.0041,
#          'sunrise': 1529493489,
#          'sunset': 1529537146},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 218.503, 'speed': 2.11}}
# Retrieving  data for record 0 parana
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -7.52, 'lon': -72.89},
#  'dt': 1529510400,
#  'id': 3663516,
#  'main': {'humidity': 48,
#           'pressure': 1018,
#           'temp': 30,
#           'temp_max': 30,
#           'temp_min': 30},
#  'name': 'Parana',
#  'sys': {'country': 'BR',
#          'id': 4485,
#          'message': 0.0132,
#          'sunrise': 1529492563,
#          'sunset': 1529534635,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 2.6}}
# Retrieving  data for record 0 resistencia
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -27.45, 'lon': -58.99},
#  'dt': 1529510400,
#  'id': 3429577,
#  'main': {'humidity': 54,
#           'pressure': 1017,
#           'temp': 24.43,
#           'temp_max': 27,
#           'temp_min': 23},
#  'name': 'Resistencia',
#  'sys': {'country': 'AR',
#          'id': 4722,
#          'message': 0.0045,
#          'sunrise': 1529491531,
#          'sunset': 1529528994,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 5.1}}
# Retrieving  data for record 0 avenal
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36, 'lon': -120.13},
#  'dt': 1529510160,
#  'id': 5325327,
#  'main': {'humidity': 39,
#           'pressure': 1014,
#           'temp': 22.6,
#           'temp_max': 26,
#           'temp_min': 18},
#  'name': 'Avenal',
#  'sys': {'country': 'US',
#          'id': 407,
#          'message': 0.0036,
#          'sunrise': 1529498644,
#          'sunset': 1529551233,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 330, 'speed': 5.7}}
# Retrieving  data for record 0 serra
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -20.13, 'lon': -40.31},
#  'dt': 1529510400,
#  'id': 3447779,
#  'main': {'humidity': 78,
#           'pressure': 1023,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Serra',
#  'sys': {'country': 'BR',
#          'id': 4601,
#          'message': 0.0052,
#          'sunrise': 1529486135,
#          'sunset': 1529525422,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 4.1}}
# Retrieving  data for record 0 winneba
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 5.35, 'lon': -0.62},
#  'dt': 1529506800,
#  'id': 2294034,
#  'main': {'humidity': 83,
#           'pressure': 1013,
#           'temp': 27,
#           'temp_max': 27,
#           'temp_min': 27},
#  'name': 'Winneba',
#  'sys': {'country': 'GH',
#          'id': 6247,
#          'message': 0.0034,
#          'sunrise': 1529473871,
#          'sunset': 1529518632,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 7.7}}
# Retrieving  data for record 0 mosquera
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 4.71, 'lon': -74.23},
#  'dt': 1529510400,
#  'id': 3674292,
#  'main': {'humidity': 52,
#           'pressure': 1029,
#           'temp': 18,
#           'temp_max': 18,
#           'temp_min': 18},
#  'name': 'Mosquera',
#  'sys': {'country': 'CO',
#          'id': 4245,
#          'message': 0.0178,
#          'sunrise': 1529491607,
#          'sunset': 1529536234,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09d',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 150, 'speed': 5.1}}
# Retrieving  data for record 0 akropong
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 5.97, 'lon': -0.09},
#  'dt': 1529506800,
#  'id': 2305027,
#  'main': {'humidity': 83,
#           'pressure': 1013,
#           'temp': 27,
#           'temp_max': 27,
#           'temp_min': 27},
#  'name': 'Akropong',
#  'sys': {'country': 'GH',
#          'id': 6247,
#          'message': 0.0041,
#          'sunrise': 1529473678,
#          'sunset': 1529518571,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 7.7}}
# Retrieving  data for record 0 bismarck
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 46.81, 'lon': -100.78},
#  'dt': 1529508900,
#  'id': 5688025,
#  'main': {'humidity': 64,
#           'pressure': 1018,
#           'temp': 21,
#           'temp_max': 21,
#           'temp_min': 21},
#  'name': 'Bismarck',
#  'sys': {'country': 'US',
#          'id': 1871,
#          'message': 0.0033,
#          'sunrise': 1529491728,
#          'sunset': 1529548859,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 3.1}}
# Retrieving  data for record 0 veinticinco de mayo
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -27.38, 'lon': -54.75},
#  'dt': 1529511414,
#  'id': 3427537,
#  'main': {'grnd_level': 1009.03,
#           'humidity': 58,
#           'pressure': 1009.03,
#           'sea_level': 1035.17,
#           'temp': 22.34,
#           'temp_max': 22.34,
#           'temp_min': 22.34},
#  'name': 'Veinticinco de Mayo',
#  'sys': {'country': 'AR',
#          'message': 0.003,
#          'sunrise': 1529490504,
#          'sunset': 1529527985},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40.003, 'speed': 2.41}}
# Retrieving  data for record 0 moose factory
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 51.26, 'lon': -80.61},
#  'dt': 1529506800,
#  'id': 6078372,
#  'main': {'humidity': 66,
#           'pressure': 1017,
#           'temp': 6,
#           'temp_max': 6,
#           'temp_min': 6},
#  'name': 'Moose Factory',
#  'sys': {'country': 'CA',
#          'id': 3683,
#          'message': 0.0035,
#          'sunrise': 1529485581,
#          'sunset': 1529545323,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 4.6}}
# Retrieving  data for record 0 kirakira
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -10.46, 'lon': 161.92},
#  'dt': 1529511414,
#  'id': 2178753,
#  'main': {'grnd_level': 1022.48,
#           'humidity': 100,
#           'pressure': 1022.48,
#           'sea_level': 1025.36,
#           'temp': 28.04,
#           'temp_max': 28.04,
#           'temp_min': 28.04},
#  'name': 'Kirakira',
#  'sys': {'country': 'SB',
#          'message': 0.0033,
#          'sunrise': 1529436512,
#          'sunset': 1529477960},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 133.503, 'speed': 6.91}}
# Retrieving  data for record 0 mecca
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 21.43, 'lon': 39.83},
#  'dt': 1529506800,
#  'id': 104515,
#  'main': {'humidity': 32,
#           'pressure': 1005,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Mecca',
#  'sys': {'country': 'SA',
#          'id': 6996,
#          'message': 0.0034,
#          'sunrise': 1529462350,
#          'sunset': 1529510735,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 180, 'speed': 5.1}}
# Retrieving  data for record 0 guerrero negro
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 27.97, 'lon': -114.04},
#  'dt': 1529511414,
#  'id': 4021858,
#  'main': {'grnd_level': 1015.27,
#           'humidity': 92,
#           'pressure': 1015.27,
#           'sea_level': 1026.7,
#           'temp': 16.34,
#           'temp_max': 16.34,
#           'temp_min': 16.34},
#  'name': 'Guerrero Negro',
#  'rain': {'3h': 0.105},
#  'sys': {'country': 'MX',
#          'message': 0.0027,
#          'sunrise': 1529498425,
#          'sunset': 1529548528},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 318.503, 'speed': 2.76}}
# Retrieving  data for record 0 saskylakh
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 71.97, 'lon': 114.09},
#  'dt': 1529511169,
#  'id': 2017155,
#  'main': {'grnd_level': 1009.92,
#           'humidity': 68,
#           'pressure': 1009.92,
#           'sea_level': 1021.18,
#           'temp': 15.74,
#           'temp_max': 15.74,
#           'temp_min': 15.74},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU', 'message': 0.0032, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 48.003, 'speed': 5.96}}
# Retrieving  data for record 0 mogocha
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 53.73, 'lon': 119.76},
#  'dt': 1529511414,
#  'id': 2019912,
#  'main': {'grnd_level': 921.49,
#           'humidity': 89,
#           'pressure': 921.49,
#           'sea_level': 1018.14,
#           'temp': 10.84,
#           'temp_max': 10.84,
#           'temp_min': 10.84},
#  'name': 'Mogocha',
#  'sys': {'country': 'RU',
#          'message': 0.0035,
#          'sunrise': 1529436600,
#          'sunset': 1529498113},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 311.003, 'speed': 0.66}}
# Retrieving  data for record 0 novoleushkovskaya
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 45.99, 'lon': 39.99},
#  'dt': 1529511414,
#  'id': 518643,
#  'main': {'grnd_level': 1016.16,
#           'humidity': 18,
#           'pressure': 1016.16,
#           'sea_level': 1025.36,
#           'temp': 34.09,
#           'temp_max': 34.09,
#           'temp_min': 34.09},
#  'name': 'Novoleushkovskaya',
#  'sys': {'country': 'RU',
#          'message': 0.0038,
#          'sunrise': 1529458148,
#          'sunset': 1529514860},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 359.003, 'speed': 2.21}}
# Retrieving  data for record 0 oum hadjer
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 13.3, 'lon': 19.7},
#  'dt': 1529511414,
#  'id': 2426370,
#  'main': {'grnd_level': 980.82,
#           'humidity': 61,
#           'pressure': 980.82,
#           'sea_level': 1024.39,
#           'temp': 28.69,
#           'temp_max': 28.69,
#           'temp_min': 28.69},
#  'name': 'Oum Hadjer',
#  'sys': {'country': 'TD',
#          'message': 0.0028,
#          'sunrise': 1529468134,
#          'sunset': 1529514614},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 185.003, 'speed': 6.76}}
# Retrieving  data for record 0 petropavlovsk-kamchatskiy
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 53.05, 'lon': 158.65},
#  'dt': 1529506800,
#  'id': 2122104,
#  'main': {'humidity': 93,
#           'pressure': 1018,
#           'temp': 9,
#           'temp_max': 9,
#           'temp_min': 9},
#  'name': 'Petropavlovsk-Kamchatskiy',
#  'sys': {'country': 'RU',
#          'id': 7248,
#          'message': 0.0089,
#          'sunrise': 1529427524,
#          'sunset': 1529488520,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 2}}
# Retrieving  data for record 0 grandview
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 38.89, 'lon': -94.53},
#  'dt': 1529508900,
#  'id': 4388460,
#  'main': {'humidity': 58,
#           'pressure': 1010,
#           'temp': 26.65,
#           'temp_max': 29,
#           'temp_min': 25},
#  'name': 'Grandview',
#  'sys': {'country': 'US',
#          'id': 1668,
#          'message': 0.0045,
#          'sunrise': 1529491978,
#          'sunset': 1529545609,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 190, 'gust': 7.7, 'speed': 6.2}}
# Retrieving  data for record 0 redmond
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 47.67, 'lon': -122.12},
#  'dt': 1529509980,
#  'id': 5808079,
#  'main': {'humidity': 60,
#           'pressure': 1015,
#           'temp': 19.22,
#           'temp_max': 22,
#           'temp_min': 17},
#  'name': 'Redmond',
#  'sys': {'country': 'US',
#          'id': 2949,
#          'message': 0.0043,
#          'sunrise': 1529496621,
#          'sunset': 1529554211,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'speed': 1.5}}
# Retrieving  data for record 0 port elizabeth
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 39.31, 'lon': -74.98},
#  'dt': 1529510160,
#  'id': 4501427,
#  'main': {'humidity': 78,
#           'pressure': 1011,
#           'temp': 27.15,
#           'temp_max': 28,
#           'temp_min': 26},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'US',
#          'id': 633,
#          'message': 0.0041,
#          'sunrise': 1529487205,
#          'sunset': 1529540996,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 4.1}}
# Retrieving  data for record 0 marin
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 47.13, 'lon': 22.81},
#  'dt': 1529508600,
#  'id': 662334,
#  'main': {'humidity': 48,
#           'pressure': 1019,
#           'temp': 30,
#           'temp_max': 30,
#           'temp_min': 30},
#  'name': 'Marin',
#  'sys': {'country': 'RO',
#          'id': 5996,
#          'message': 0.0038,
#          'sunrise': 1529461978,
#          'sunset': 1529519278,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 2.6}}
# Retrieving  data for record 0 aklavik
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 68.22, 'lon': -135.01},
#  'dt': 1529506800,
#  'id': 5882953,
#  'main': {'humidity': 87,
#           'pressure': 1018,
#           'temp': 6,
#           'temp_max': 6,
#           'temp_min': 6},
#  'name': 'Aklavik',
#  'sys': {'country': 'CA',
#          'id': 3513,
#          'message': 0.0037,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 1.5}}
# Retrieving  data for record 0 bluff
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1529511415,
#  'id': 2175403,
#  'main': {'grnd_level': 1012.35,
#           'humidity': 83,
#           'pressure': 1012.35,
#           'sea_level': 1036.3,
#           'temp': 6.64,
#           'temp_max': 6.64,
#           'temp_min': 6.64},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0036,
#          'sunrise': 1529441093,
#          'sunset': 1529479548},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 127.003, 'speed': 2.31}}
# Retrieving  data for record 0 alyangula
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -13.85, 'lon': 136.42},
#  'dt': 1529511416,
#  'id': 2079582,
#  'main': {'grnd_level': 1029.29,
#           'humidity': 100,
#           'pressure': 1029.29,
#           'sea_level': 1029.74,
#           'temp': 22.74,
#           'temp_max': 22.74,
#           'temp_min': 22.74},
#  'name': 'Alyangula',
#  'sys': {'country': 'AU',
#          'message': 0.0044,
#          'sunrise': 1529443001,
#          'sunset': 1529483713},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 123.503, 'speed': 5.16}}
# Retrieving  data for record 0 ayan
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 40.67, 'lon': 33.6},
#  'dt': 1529511416,
#  'id': 749747,
#  'main': {'grnd_level': 883.55,
#           'humidity': 75,
#           'pressure': 883.55,
#           'sea_level': 1027.26,
#           'temp': 18.89,
#           'temp_max': 18.89,
#           'temp_min': 18.89},
#  'name': 'Ayan',
#  'rain': {'3h': 1.24},
#  'sys': {'country': 'TR',
#          'message': 0.0036,
#          'sunrise': 1529460875,
#          'sunset': 1529515201},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 15.003, 'speed': 1.31}}
# Retrieving  data for record 0 attawapiskat
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city attawapiskat
# error code: 404
# message: city not found
# Retrieving  data for record 0 pisco
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -13.71, 'lon': -76.2},
#  'dt': 1529510400,
#  'id': 3932145,
#  'main': {'humidity': 93,
#           'pressure': 1017,
#           'temp': 17,
#           'temp_max': 17,
#           'temp_min': 17},
#  'name': 'Pisco',
#  'sys': {'country': 'PE',
#          'id': 4405,
#          'message': 0.0039,
#          'sunrise': 1529494022,
#          'sunset': 1529534765,
#          'type': 1},
#  'visibility': 1500,
#  'weather': [{'description': 'light intensity drizzle',
#               'icon': '09d',
#               'id': 300,
#               'main': 'Drizzle'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 270, 'speed': 4.6}}
# Retrieving  data for record 0 chiang rai
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 19.9, 'lon': 99.84},
#  'dt': 1529506800,
#  'id': 1153669,
#  'main': {'humidity': 100,
#           'pressure': 1008,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Chiang Rai',
#  'sys': {'country': 'TH',
#          'id': 7935,
#          'message': 0.006,
#          'sunrise': 1529448133,
#          'sunset': 1529496143,
#          'type': 1},
#  'visibility': 6000,
#  'weather': [{'description': 'thunderstorm with light rain',
#               'icon': '11n',
#               'id': 200,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 350, 'speed': 2.6}}
# Retrieving  data for record 0 devils lake
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 48.11, 'lon': -98.87},
#  'dt': 1529508900,
#  'id': 5058868,
#  'main': {'humidity': 53,
#           'pressure': 1018,
#           'temp': 23.95,
#           'temp_max': 25,
#           'temp_min': 23},
#  'name': 'Devils Lake',
#  'sys': {'country': 'US',
#          'id': 1849,
#          'message': 0.0038,
#          'sunrise': 1529490919,
#          'sunset': 1529548751,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'speed': 1.5}}
# Retrieving  data for record 0 mar del plata
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1529511416,
#  'id': 3863379,
#  'main': {'grnd_level': 991.85,
#           'humidity': 57,
#           'pressure': 991.85,
#           'sea_level': 1013.36,
#           'temp': 9.69,
#           'temp_max': 9.69,
#           'temp_min': 9.69},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.0041,
#          'sunrise': 1529496861,
#          'sunset': 1529527759},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289.503, 'speed': 12.11}}
# Retrieving  data for record 0 sawtell
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -30.38, 'lon': 153.1},
#  'dt': 1529508600,
#  'id': 2150163,
#  'main': {'humidity': 67,
#           'pressure': 1024,
#           'temp': 14,
#           'temp_max': 14,
#           'temp_min': 14},
#  'name': 'Sawtell',
#  'sys': {'country': 'AU',
#          'id': 8179,
#          'message': 0.0043,
#          'sunrise': 1529441023,
#          'sunset': 1529477684,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 4.1}}
# Retrieving  data for record 0 pankrushikha
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 53.83, 'lon': 80.35},
#  'dt': 1529511417,
#  'id': 1495613,
#  'main': {'grnd_level': 994.84,
#           'humidity': 63,
#           'pressure': 994.84,
#           'sea_level': 1017.33,
#           'temp': 17.24,
#           'temp_max': 17.24,
#           'temp_min': 17.24},
#  'name': 'Pankrushikha',
#  'rain': {'3h': 0.3525},
#  'sys': {'country': 'RU',
#          'message': 0.004,
#          'sunrise': 1529446021,
#          'sunset': 1529507612},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 258.003, 'speed': 5.06}}
# Retrieving  data for record 0 saurimo
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.66, 'lon': 20.4},
#  'dt': 1529506800,
#  'id': 145531,
#  'main': {'humidity': 25,
#           'pressure': 1018,
#           'temp': 30,
#           'temp_max': 30,
#           'temp_min': 30},
#  'name': 'Saurimo',
#  'sys': {'country': 'AO',
#          'id': 6825,
#          'message': 0.004,
#          'sunrise': 1529470397,
#          'sunset': 1529512015,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 112.003, 'speed': 1.86}}
# Retrieving  data for record 0 deputatskiy
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 69.3, 'lon': 139.9},
#  'dt': 1529511417,
#  'id': 2028164,
#  'main': {'grnd_level': 958.85,
#           'humidity': 26,
#           'pressure': 958.85,
#           'sea_level': 1021.79,
#           'temp': 14.59,
#           'temp_max': 14.59,
#           'temp_min': 14.59},
#  'name': 'Deputatskiy',
#  'sys': {'country': 'RU', 'message': 0.0035, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 132.503, 'speed': 3.66}}
# Retrieving  data for record 0 sun valley
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 43.7, 'lon': -114.35},
#  'dt': 1529506260,
#  'id': 5609286,
#  'main': {'humidity': 76,
#           'pressure': 1025,
#           'temp': 12.4,
#           'temp_max': 13,
#           'temp_min': 12},
#  'name': 'Sun Valley',
#  'sys': {'country': 'US',
#          'id': 920,
#          'message': 0.0264,
#          'sunrise': 1529495741,
#          'sunset': 1529551361,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 4.1}}
# Retrieving  data for record 0 paitan
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 23.49, 'lon': 113.78},
#  'dt': 1529508600,
#  'id': 1799112,
#  'main': {'humidity': 79,
#           'pressure': 1005,
#           'temp': 30,
#           'temp_max': 30,
#           'temp_min': 30},
#  'name': 'Paitan',
#  'sys': {'country': 'CN',
#          'id': 7414,
#          'message': 0.0033,
#          'sunrise': 1529444340,
#          'sunset': 1529493244,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 120, 'speed': 2}}
# Retrieving  data for record 0 buala
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -8.15, 'lon': 159.59},
#  'dt': 1529511417,
#  'id': 2109528,
#  'main': {'grnd_level': 1015.83,
#           'humidity': 97,
#           'pressure': 1015.83,
#           'sea_level': 1024.95,
#           'temp': 27.09,
#           'temp_max': 27.09,
#           'temp_min': 27.09},
#  'name': 'Buala',
#  'rain': {'3h': 0.115},
#  'sys': {'country': 'SB',
#          'message': 0.0045,
#          'sunrise': 1529436826,
#          'sunset': 1529478765},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 129.503, 'speed': 4.91}}
# Retrieving  data for record 0 tuatapere
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -46.13, 'lon': 167.69},
#  'dt': 1529511417,
#  'id': 2180815,
#  'main': {'grnd_level': 1012.35,
#           'humidity': 100,
#           'pressure': 1012.35,
#           'sea_level': 1038.57,
#           'temp': 2.49,
#           'temp_max': 2.49,
#           'temp_min': 2.49},
#  'name': 'Tuatapere',
#  'sys': {'country': 'NZ',
#          'message': 0.0033,
#          'sunrise': 1529440330,
#          'sunset': 1529471371},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 54.003, 'speed': 2.16}}
# Retrieving  data for record 0 santa maria
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -29.69, 'lon': -53.81},
#  'dt': 1529506800,
#  'id': 3450083,
#  'main': {'humidity': 72,
#           'pressure': 1021,
#           'temp': 19,
#           'temp_max': 19,
#           'temp_min': 19},
#  'name': 'Santa Maria',
#  'sys': {'country': 'BR',
#          'id': 4573,
#          'message': 0.0029,
#          'sunrise': 1529490592,
#          'sunset': 1529527446,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 1.5}}
# Retrieving  data for record 0 matranovak
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 48.04, 'lon': 19.98},
#  'dt': 1529511419,
#  'id': 3048291,
#  'main': {'grnd_level': 1002.3,
#           'humidity': 66,
#           'pressure': 1002.3,
#           'sea_level': 1033.75,
#           'temp': 26.74,
#           'temp_max': 26.74,
#           'temp_min': 26.74},
#  'name': 'Matranovak',
#  'sys': {'country': 'HU',
#          'message': 0.003,
#          'sunrise': 1529462411,
#          'sunset': 1529520203},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 54.503, 'speed': 1.61}}
# Retrieving  data for record 0 channel-port aux basques
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 47.57, 'lon': -59.14},
#  'dt': 1529511419,
#  'id': 5919815,
#  'main': {'grnd_level': 1016.16,
#           'humidity': 98,
#           'pressure': 1016.16,
#           'sea_level': 1017.29,
#           'temp': 7.99,
#           'temp_max': 7.99,
#           'temp_min': 7.99},
#  'name': 'Channel-Port aux Basques',
#  'sys': {'country': 'CA',
#          'message': 0.0029,
#          'sunrise': 1529481531,
#          'sunset': 1529539066},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 273.503, 'speed': 6.06}}
# Retrieving  data for record 0 leningradskiy
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 69.38, 'lon': 178.42},
#  'dt': 1529511419,
#  'id': 2123814,
#  'main': {'grnd_level': 1031.07,
#           'humidity': 100,
#           'pressure': 1031.07,
#           'sea_level': 1033.87,
#           'temp': -1.76,
#           'temp_max': -1.76,
#           'temp_min': -1.76},
#  'name': 'Leningradskiy',
#  'sys': {'country': 'RU', 'message': 0.0027, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120.003, 'speed': 5.81}}
# Retrieving  data for record 0 ruatoria
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city ruatoria
# error code: 404
# message: city not found
# Retrieving  data for record 0 kilindoni
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -7.91, 'lon': 39.67},
#  'dt': 1529511419,
#  'id': 157429,
#  'main': {'grnd_level': 1030.02,
#           'humidity': 94,
#           'pressure': 1030.02,
#           'sea_level': 1030.14,
#           'temp': 26.09,
#           'temp_max': 26.09,
#           'temp_min': 26.09},
#  'name': 'Kilindoni',
#  'sys': {'country': 'TZ',
#          'message': 0.0035,
#          'sunrise': 1529465586,
#          'sunset': 1529507575},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 162.503, 'speed': 4.76}}
# Retrieving  data for record 0 angouleme
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 45.65, 'lon': 0.15},
#  'dt': 1529510400,
#  'id': 3037598,
#  'main': {'humidity': 43,
#           'pressure': 1017,
#           'temp': 31.53,
#           'temp_max': 32,
#           'temp_min': 31},
#  'name': 'Angouleme',
#  'sys': {'country': 'FR',
#          'id': 5540,
#          'message': 0.0035,
#          'sunrise': 1529467796,
#          'sunset': 1529524338,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'speed': 1.5}}
# Retrieving  data for record 0 kamiiso
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 41.82, 'lon': 140.65},
#  'dt': 1529511420,
#  'id': 2129766,
#  'main': {'grnd_level': 989.41,
#           'humidity': 98,
#           'pressure': 989.41,
#           'sea_level': 1014.25,
#           'temp': 15.09,
#           'temp_max': 15.09,
#           'temp_min': 15.09},
#  'name': 'Kamiiso',
#  'rain': {'3h': 4.025},
#  'sys': {'country': 'JP',
#          'message': 0.0037,
#          'sunrise': 1529434943,
#          'sunset': 1529489741},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 122.003, 'speed': 1.81}}
# Retrieving  data for record 0 bridlington
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 54.08, 'lon': -0.19},
#  'dt': 1529509800,
#  'id': 2654728,
#  'main': {'humidity': 77,
#           'pressure': 1016,
#           'temp': 18.42,
#           'temp_max': 21,
#           'temp_min': 15},
#  'name': 'Bridlington',
#  'sys': {'country': 'GB',
#          'id': 5181,
#          'message': 0.0039,
#          'sunrise': 1529465254,
#          'sunset': 1529527044,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 5.7}}
# Retrieving  data for record 0 labuhan
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -2.54, 'lon': 115.51},
#  'dt': 1529511200,
#  'id': 1641899,
#  'main': {'grnd_level': 1000.92,
#           'humidity': 99,
#           'pressure': 1000.92,
#           'sea_level': 1026.78,
#           'temp': 23.04,
#           'temp_max': 23.04,
#           'temp_min': 23.04},
#  'name': 'Labuhan',
#  'sys': {'country': 'ID',
#          'message': 0.039,
#          'sunrise': 1529446819,
#          'sunset': 1529489933},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132.503, 'speed': 0.96}}
# Retrieving  data for record 0 delvine
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': 20.1},
#  'dt': 1529509800,
#  'id': 363383,
#  'main': {'humidity': 61,
#           'pressure': 1015,
#           'temp': 26.46,
#           'temp_max': 27,
#           'temp_min': 26},
#  'name': 'Delvine',
#  'sys': {'country': 'AL',
#          'id': 5683,
#          'message': 0.0035,
#          'sunrise': 1529464258,
#          'sunset': 1529518298,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 4.1}}
# Retrieving  data for record 0 gangotri
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city gangotri
# error code: 404
# message: city not found
# Retrieving  data for record 0 honiara
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -9.43, 'lon': 159.96},
#  'dt': 1529506800,
#  'id': 2108502,
#  'main': {'humidity': 100,
#           'pressure': 1012,
#           'temp': 25,
#           'temp_max': 25,
#           'temp_min': 25},
#  'name': 'Honiara',
#  'sys': {'country': 'SB',
#          'id': 8147,
#          'message': 0.0034,
#          'sunrise': 1529436873,
#          'sunset': 1529478540,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 180, 'speed': 2.1}}
# Retrieving  data for record 0 umzimvubu
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city umzimvubu
# error code: 404
# message: city not found
# Retrieving  data for record 0 san pedro
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.68, 'lon': -59.66},
#  'dt': 1529511421,
#  'id': 3428576,
#  'main': {'grnd_level': 1030.59,
#           'humidity': 65,
#           'pressure': 1030.59,
#           'sea_level': 1031.44,
#           'temp': 19.84,
#           'temp_max': 19.84,
#           'temp_min': 19.84},
#  'name': 'San Pedro',
#  'sys': {'country': 'AR',
#          'message': 0.0253,
#          'sunrise': 1529492578,
#          'sunset': 1529528269},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 2.50302, 'speed': 2.26}}
# Retrieving  data for record 0 doctor arroyo
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 23.67, 'lon': -100.18},
#  'dt': 1529511421,
#  'id': 4011873,
#  'main': {'grnd_level': 840.43,
#           'humidity': 96,
#           'pressure': 840.43,
#           'sea_level': 1022.64,
#           'temp': 18.04,
#           'temp_max': 18.04,
#           'temp_min': 18.04},
#  'name': 'Doctor Arroyo',
#  'rain': {'3h': 0.11},
#  'sys': {'country': 'MX',
#          'message': 0.0038,
#          'sunrise': 1529495674,
#          'sunset': 1529544625},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 298.003, 'speed': 1.66}}
# Retrieving  data for record 0 zharkent
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 44.17, 'lon': 80},
#  'dt': 1529511421,
#  'id': 1520253,
#  'main': {'grnd_level': 834.1,
#           'humidity': 44,
#           'pressure': 834.1,
#           'sea_level': 1021.59,
#           'temp': 15.94,
#           'temp_max': 15.94,
#           'temp_min': 15.94},
#  'name': 'Zharkent',
#  'sys': {'country': 'KZ',
#          'message': 0.0035,
#          'sunrise': 1529448983,
#          'sunset': 1529504818},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 299.503, 'speed': 1.31}}
# Retrieving  data for record 0 pangnirtung
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 66.15, 'lon': -65.72},
#  'dt': 1529506800,
#  'id': 6096551,
#  'main': {'humidity': 93,
#           'pressure': 1000,
#           'temp': 3,
#           'temp_max': 3,
#           'temp_min': 3},
#  'name': 'Pangnirtung',
#  'sys': {'country': 'CA',
#          'id': 3605,
#          'message': 0.2448,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 5.7}}
# Retrieving  data for record 0 mount isa
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.73, 'lon': 139.49},
#  'dt': 1529510400,
#  'id': 2065594,
#  'main': {'humidity': 34,
#           'pressure': 1021,
#           'temp': 12,
#           'temp_max': 12,
#           'temp_min': 12},
#  'name': 'Mount Isa',
#  'sys': {'country': 'AU',
#          'id': 8171,
#          'message': 0.003,
#          'sunrise': 1529443047,
#          'sunset': 1529482193,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 4.1}}
# Retrieving  data for record 0 narsaq
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 60.91, 'lon': -46.05},
#  'dt': 1529509800,
#  'id': 3421719,
#  'main': {'humidity': 30,
#           'pressure': 992,
#           'temp': 12,
#           'temp_max': 12,
#           'temp_min': 12},
#  'name': 'Narsaq',
#  'sys': {'country': 'GL',
#          'id': 4791,
#          'message': 0.0046,
#          'sunrise': 1529472529,
#          'sunset': 1529541785,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'gust': 25.7, 'speed': 20.6}}
# Retrieving  data for record 0 nizhniy tagil
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 57.92, 'lon': 59.97},
#  'dt': 1529511422,
#  'id': 520494,
#  'main': {'grnd_level': 980.42,
#           'humidity': 61,
#           'pressure': 980.42,
#           'sea_level': 1008.34,
#           'temp': 20.39,
#           'temp_max': 20.39,
#           'temp_min': 20.39},
#  'name': 'Nizhniy Tagil',
#  'rain': {'3h': 0.54},
#  'sys': {'country': 'RU',
#          'message': 0.0031,
#          'sunrise': 1529449024,
#          'sunset': 1529514393},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 216.503, 'speed': 3.36}}
# Retrieving  data for record 0 mabaruma
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 8.2, 'lon': -59.78},
#  'dt': 1529511423,
#  'id': 3377301,
#  'main': {'grnd_level': 1027.67,
#           'humidity': 98,
#           'pressure': 1027.67,
#           'sea_level': 1029.13,
#           'temp': 25.79,
#           'temp_max': 25.79,
#           'temp_min': 25.79},
#  'name': 'Mabaruma',
#  'rain': {'3h': 0.28},
#  'sys': {'country': 'GY',
#          'message': 0.0319,
#          'sunrise': 1529487769,
#          'sunset': 1529533136},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 63.503, 'speed': 2.11}}
# Retrieving  data for record 0 maarianhamina
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city maarianhamina
# error code: 404
# message: city not found
# Retrieving  data for record 0 victoria
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1529508600,
#  'id': 1733782,
#  'main': {'humidity': 94,
#           'pressure': 1012,
#           'temp': 27,
#           'temp_max': 27,
#           'temp_min': 27},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 8115,
#          'message': 0.004,
#          'sunrise': 1529446068,
#          'sunset': 1529490815,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 47.003, 'speed': 0.76}}
# Retrieving  data for record 0 salvacion
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 14.63, 'lon': 120.99},
#  'dt': 1529506800,
#  'id': 1692193,
#  'main': {'humidity': 100,
#           'pressure': 1012,
#           'temp': 27,
#           'temp_max': 27,
#           'temp_min': 27},
#  'name': 'Salvacion',
#  'sys': {'country': 'PH',
#          'id': 7706,
#          'message': 0.0036,
#          'sunrise': 1529443671,
#          'sunset': 1529490451,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 1.5}}
# Retrieving  data for record 0 danilov
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 58.19, 'lon': 40.17},
#  'dt': 1529511424,
#  'id': 567183,
#  'main': {'grnd_level': 1000.76,
#           'humidity': 79,
#           'pressure': 1000.76,
#           'sea_level': 1016.89,
#           'temp': 14.99,
#           'temp_max': 14.99,
#           'temp_min': 14.99},
#  'name': 'Danilov',
#  'rain': {'3h': 0.78},
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1529453626,
#          'sunset': 1529519296},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 290.503, 'speed': 9.01}}
# Retrieving  data for record 0 simbahan
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 6.3, 'lon': 120.58},
#  'dt': 1529511424,
#  'id': 1695180,
#  'main': {'grnd_level': 1025.72,
#           'humidity': 98,
#           'pressure': 1025.72,
#           'sea_level': 1025.8,
#           'temp': 29.64,
#           'temp_max': 29.64,
#           'temp_min': 29.64},
#  'name': 'Simbahan',
#  'sys': {'country': 'PH',
#          'message': 0.0029,
#          'sunrise': 1529444678,
#          'sunset': 1529489641},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 161.003, 'speed': 3.46}}
# Retrieving  data for record 0 yaan
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 7.38, 'lon': 8.57},
#  'dt': 1529511424,
#  'id': 2338660,
#  'main': {'grnd_level': 1009.68,
#           'humidity': 84,
#           'pressure': 1009.68,
#           'sea_level': 1026.53,
#           'temp': 25.49,
#           'temp_max': 25.49,
#           'temp_min': 25.49},
#  'name': 'Yaan',
#  'sys': {'country': 'NG',
#          'message': 0.0035,
#          'sunrise': 1529471450,
#          'sunset': 1529516642},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 205.003, 'speed': 4.56}}
# Retrieving  data for record 0 port hardy
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 50.7, 'lon': -127.42},
#  'dt': 1529506800,
#  'id': 6111862,
#  'main': {'humidity': 100,
#           'pressure': 1016,
#           'temp': 11,
#           'temp_max': 11,
#           'temp_min': 11},
#  'name': 'Port Hardy',
#  'sys': {'country': 'CA',
#          'id': 3322,
#          'message': 0.0228,
#          'sunrise': 1529497000,
#          'sunset': 1529556377,
#          'type': 1},
#  'visibility': 402,
#  'weather': [{'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 80, 'speed': 2.6}}
# Retrieving  data for record 0 aventura
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 25.96, 'lon': -80.14},
#  'dt': 1529510160,
#  'id': 4146429,
#  'main': {'humidity': 52,
#           'pressure': 1016,
#           'temp': 31.66,
#           'temp_max': 33,
#           'temp_min': 31},
#  'name': 'Aventura',
#  'sys': {'country': 'US',
#          'id': 662,
#          'message': 0.0037,
#          'sunrise': 1529490563,
#          'sunset': 1529540116,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 3.6}}
# Retrieving  data for record 0 aranos
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24.14, 'lon': 19.11},
#  'dt': 1529511424,
#  'id': 3358666,
#  'main': {'grnd_level': 895.38,
#           'humidity': 11,
#           'pressure': 895.38,
#           'sea_level': 1028.56,
#           'temp': 24.74,
#           'temp_max': 24.74,
#           'temp_min': 24.74},
#  'name': 'Aranos',
#  'sys': {'country': 'NA',
#          'message': 0.0032,
#          'sunrise': 1529472358,
#          'sunset': 1529510673},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 341.503, 'speed': 3.06}}
# ...
#  'wind': {'deg': 180, 'speed': 3.6}}
# Retrieving  data for record 0 kiruna
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 67.86, 'lon': 20.23},
#  'dt': 1529509800,
#  'id': 605155,
#  'main': {'humidity': 66,
#           'pressure': 995,
#           'temp': 11,
#           'temp_max': 11,
#           'temp_min': 11},
#  'name': 'Kiruna',
#  'sys': {'country': 'SE',
#          'id': 5407,
#          'message': 0.0035,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 3.6}}
# Retrieving  data for record 0 pavilosta
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 56.89, 'lon': 21.19},
#  'dt': 1529509800,
#  'id': 456827,
#  'main': {'humidity': 72,
#           'pressure': 1016,
#           'temp': 16.48,
#           'temp_max': 17,
#           'temp_min': 16},
#  'name': 'Pavilosta',
#  'sys': {'country': 'LV',
#          'id': 7367,
#          'message': 0.0034,
#          'sunrise': 1529458871,
#          'sunset': 1529523163,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 7.7}}
# Retrieving  data for record 0 tarakan
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 3.3, 'lon': 117.63},
#  'dt': 1529511492,
#  'id': 1624725,
#  'main': {'grnd_level': 1025.64,
#           'humidity': 99,
#           'pressure': 1025.64,
#           'sea_level': 1026.13,
#           'temp': 27.64,
#           'temp_max': 27.64,
#           'temp_min': 27.64},
#  'name': 'Tarakan',
#  'sys': {'country': 'ID',
#          'message': 0.0045,
#          'sunrise': 1529445702,
#          'sunset': 1529490033},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 135.003, 'speed': 2.36}}
# Retrieving  data for record 0 russell
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.01, 'lon': -68.8},
#  'dt': 1529510400,
#  'id': 3844421,
#  'main': {'humidity': 41,
#           'pressure': 1015,
#           'temp': 16,
#           'temp_max': 16,
#           'temp_min': 16},
#  'name': 'Russell',
#  'sys': {'country': 'AR',
#          'id': 4700,
#          'message': 0.0033,
#          'sunrise': 1529494670,
#          'sunset': 1529530565,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 50, 'speed': 3.1}}
# Retrieving  data for record 0 crab hill
# {'cod': '404', 'message': 'city not found'}
# Error in getting data for city crab hill
# error code: 404
# message: city not found
# Retrieving  data for record 0 taybad
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 34.74, 'lon': 60.78},
#  'dt': 1529511492,
#  'id': 1159384,
#  'main': {'grnd_level': 904.06,
#           'humidity': 21,
#           'pressure': 904.06,
#           'sea_level': 1021.35,
#           'temp': 29.04,
#           'temp_max': 29.04,
#           'temp_min': 29.04},
#  'name': 'Taybad',
#  'sys': {'country': 'IR',
#          'message': 0.0027,
#          'sunrise': 1529455433,
#          'sunset': 1529507595},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 42.003, 'speed': 6.01}}
# Retrieving  data for record 0 the pas
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 53.82, 'lon': -101.24},
#  'dt': 1529506800,
#  'id': 6164499,
#  'main': {'humidity': 60,
#           'pressure': 1014,
#           'temp': 22,
#           'temp_max': 22,
#           'temp_min': 22},
#  'name': 'The Pas',
#  'sys': {'country': 'CA',
#          'id': 3405,
#          'message': 0.0039,
#          'sunrise': 1529489612,
#          'sunset': 1529551196,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 2.6}}
# Retrieving  data for record 0 kirkland lake
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 48.15, 'lon': -80.03},
#  'dt': 1529509920,
#  'id': 5992836,
#  'main': {'humidity': 100,
#           'pressure': 1013,
#           'temp': 14,
#           'temp_max': 14,
#           'temp_min': 14},
#  'name': 'Kirkland Lake',
#  'sys': {'country': 'CA',
#          'id': 3646,
#          'message': 0.0075,
#          'sunrise': 1529486386,
#          'sunset': 1529544240,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 360, 'gust': 7.7, 'speed': 5.1}}
# Retrieving  data for record 0 upernavik
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 72.79, 'lon': -56.15},
#  'dt': 1529511493,
#  'id': 3418910,
#  'main': {'grnd_level': 1014.94,
#           'humidity': 94,
#           'pressure': 1014.94,
#           'sea_level': 1018.02,
#           'temp': 0.54,
#           'temp_max': 0.54,
#           'temp_min': 0.54},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL', 'message': 0.0036, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 28.503, 'speed': 2.56}}
# Retrieving  data for record 0 tolaga bay
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -38.37, 'lon': 178.3},
#  'dt': 1529511493,
#  'id': 2180991,
#  'main': {'grnd_level': 1010.81,
#           'humidity': 83,
#           'pressure': 1010.81,
#           'sea_level': 1031.44,
#           'temp': 11.04,
#           'temp_max': 11.04,
#           'temp_min': 11.04},
#  'name': 'Tolaga Bay',
#  'rain': {'3h': 0.175},
#  'sys': {'country': 'NZ',
#          'message': 0.0034,
#          'sunrise': 1529436224,
#          'sunset': 1529470385},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 95.003, 'speed': 7.71}}
# Retrieving  data for record 0 benidorm
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 38.54, 'lon': -0.13},
#  'dt': 1529510400,
#  'id': 2521088,
#  'main': {'humidity': 50,
#           'pressure': 1018,
#           'temp': 26,
#           'temp_max': 26,
#           'temp_min': 26},
#  'name': 'Benidorm',
#  'sys': {'country': 'ES',
#          'id': 5464,
#          'message': 0.0038,
#          'sunrise': 1529469384,
#          'sunset': 1529522884,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 3.6}}
# Retrieving  data for record 0 chuy
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -33.69, 'lon': -53.46},
#  'dt': 1529511493,
#  'id': 3443061,
#  'main': {'grnd_level': 1031.8,
#           'humidity': 90,
#           'pressure': 1031.8,
#           'sea_level': 1033.38,
#           'temp': 17.54,
#           'temp_max': 17.54,
#           'temp_min': 17.54},
#  'name': 'Chuy',
#  'sys': {'country': 'UY',
#          'message': 0.0033,
#          'sunrise': 1529491091,
#          'sunset': 1529526779},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280.503, 'speed': 3.46}}
# Retrieving  data for record 0 susanville
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.42, 'lon': -120.65},
#  'dt': 1529511300,
#  'id': 5572400,
#  'main': {'humidity': 43,
#           'pressure': 1020,
#           'temp': 21,
#           'temp_max': 21,
#           'temp_min': 21},
#  'name': 'Susanville',
#  'sys': {'country': 'US',
#          'id': 496,
#          'message': 0.0038,
#          'sunrise': 1529497950,
#          'sunset': 1529552176,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 1.5}}
# Retrieving  data for record 0 kaka
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 37.35, 'lon': 59.62},
#  'dt': 1529511494,
#  'id': 161901,
#  'main': {'grnd_level': 907.95,
#           'humidity': 30,
#           'pressure': 907.95,
#           'sea_level': 1024.18,
#           'temp': 26.09,
#           'temp_max': 26.09,
#           'temp_min': 26.09},
#  'name': 'Kaka',
#  'sys': {'country': 'TM',
#          'message': 0.0036,
#          'sunrise': 1529455260,
#          'sunset': 1529508324},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65.003, 'speed': 2.06}}
# Retrieving  data for record 0 nerchinskiy zavod
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 51.31, 'lon': 119.61},
#  'dt': 1529511494,
#  'id': 2019323,
#  'main': {'grnd_level': 928.13,
#           'humidity': 84,
#           'pressure': 928.13,
#           'sea_level': 1018.23,
#           'temp': 13.59,
#           'temp_max': 13.59,
#           'temp_min': 13.59},
#  'name': 'Nerchinskiy Zavod',
#  'rain': {'3h': 1.015},
#  'sys': {'country': 'RU',
#          'message': 0.0068,
#          'sunrise': 1529437506,
#          'sunset': 1529497280},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 283.003, 'speed': 1.21}}
# Retrieving  data for record 0 yellowknife
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1529506800,
#  'id': 6185377,
#  'main': {'humidity': 53,
#           'pressure': 1011,
#           'temp': 23,
#           'temp_max': 23,
#           'temp_min': 23},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 3558,
#          'message': 0.004,
#          'sunrise': 1529487577,
#          'sunset': 1529559539,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 1.5}}
# Retrieving  data for record 0 jitauna
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -14.02, 'lon': -39.89},
#  'dt': 1529511494,
#  'id': 3459876,
#  'main': {'grnd_level': 1000.68,
#           'humidity': 94,
#           'pressure': 1000.68,
#           'sea_level': 1034.48,
#           'temp': 22.49,
#           'temp_max': 22.49,
#           'temp_min': 22.49},
#  'name': 'Jitauna',
#  'rain': {'3h': 0.395},
#  'sys': {'country': 'BR',
#          'message': 0.007,
#          'sunrise': 1529485340,
#          'sunset': 1529526015},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 129.503, 'speed': 2.91}}
# Retrieving  data for record 0 goba
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 7.01, 'lon': 39.97},
#  'dt': 1529511494,
#  'id': 336350,
#  'main': {'grnd_level': 787.01,
#           'humidity': 86,
#           'pressure': 787.01,
#           'sea_level': 1023.41,
#           'temp': 15.89,
#           'temp_max': 15.89,
#           'temp_min': 15.89},
#  'name': 'Goba',
#  'rain': {'3h': 0.95},
#  'sys': {'country': 'ET',
#          'message': 0.0033,
#          'sunrise': 1529463952,
#          'sunset': 1529509065},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 118.503, 'speed': 1.36}}
# Retrieving  data for record 0 strezhevoy
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 60.73, 'lon': 77.6},
#  'dt': 1529508600,
#  'id': 1490796,
#  'main': {'humidity': 93,
#           'pressure': 988,
#           'temp': 15,
#           'temp_max': 15,
#           'temp_min': 15},
#  'name': 'Strezhevoy',
#  'sys': {'country': 'RU',
#          'id': 7314,
#          'message': 0.0048,
#          'sunrise': 1529442988,
#          'sunset': 1529511966,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 270, 'gust': 12, 'speed': 6}}
# Retrieving  data for record 0 chifeng
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.27, 'lon': 118.96},
#  'dt': 1529511494,
#  'id': 2038067,
#  'main': {'grnd_level': 925.29,
#           'humidity': 52,
#           'pressure': 925.29,
#           'sea_level': 1021.18,
#           'temp': 13.64,
#           'temp_max': 13.64,
#           'temp_min': 13.64},
#  'name': 'Chifeng',
#  'sys': {'country': 'CN',
#          'message': 0.0038,
#          'sunrise': 1529440054,
#          'sunset': 1529495043},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310.503, 'speed': 1.36}}
# Retrieving  data for record 0 boa vista
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 2.82, 'lon': -60.67},
#  'dt': 1529510400,
#  'id': 3664980,
#  'main': {'humidity': 83,
#           'pressure': 1016,
#           'temp': 26,
#           'temp_max': 26,
#           'temp_min': 26},
#  'name': 'Boa Vista',
#  'sys': {'country': 'BR',
#          'id': 4465,
#          'message': 0.0036,
#          'sunrise': 1529488551,
#          'sunset': 1529532781,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 210, 'speed': 2.6}}
# Retrieving  data for record 0 hobart
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1529510400,
#  'id': 2163355,
#  'main': {'humidity': 75,
#           'pressure': 1023,
#           'temp': 7,
#           'temp_max': 7,
#           'temp_min': 7},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0044,
#          'sunrise': 1529444509,
#          'sunset': 1529476967,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 3.6}}
# Retrieving  data for record 0 skjervoy
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 70.03, 'lon': 20.97},
#  'dt': 1529509800,
#  'id': 777682,
#  'main': {'humidity': 93,
#           'pressure': 997,
#           'temp': 9,
#           'temp_max': 9,
#           'temp_min': 9},
#  'name': 'Skjervoy',
#  'sys': {'country': 'NO',
#          'id': 5297,
#          'message': 0.0038,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 5.1}}
# Retrieving  data for record 0 airai
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -8.93, 'lon': 125.41},
#  'dt': 1529511496,
#  'id': 1651810,
#  'main': {'grnd_level': 950.75,
#           'humidity': 90,
#           'pressure': 950.75,
#           'sea_level': 1027.83,
#           'temp': 19.99,
#           'temp_max': 19.99,
#           'temp_min': 19.99},
#  'name': 'Airai',
#  'sys': {'country': 'TL',
#          'message': 0.0034,
#          'sunrise': 1529445113,
#          'sunset': 1529486887},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 106.503, 'speed': 0.76}}
# Data Retrieval Complete
# ---------------------------------------------------------
# Num cities weather not found52

# %%
print(len(citylist))
print(len(cloudiness))
print(len(tempmax))
print(len(humidity))
print(len(lat))
# Out:
# 503
# 503
# 503
# 503
# 503

# %%
#store results into a dictionary and convert to a dataframe. 
weatherdict=dict()
weatherdict={"City":citylist,"Cloudiness":cloudiness,"Country_code":cnycode,"Date":date,
             "Humidity":humidity,"Latitude":lat,"Longitude":long,"Max_temp":tempmax,
             "Wind_speed":windspeed}
print(len(weatherdict))

weather_df = pd.DataFrame(weatherdict)
weather_df.tail(10)
# Out:
# 9
#                   City  Cloudiness Country_code        Date  Humidity  \
# 493  Nerchinskiy Zavod          20           RU  1529511494        84
# 494        Yellowknife          20           CA  1529506800        53
# 495            Jitauna          88           BR  1529511494        94
# 496               Goba          48           ET  1529511494        86
# 497         Strezhevoy          90           RU  1529508600        93
# 498            Chifeng           0           CN  1529511494        52
# 499          Boa Vista          75           BR  1529510400        83
# 500             Hobart          20           AU  1529510400        75
# 501           Skjervoy          75           NO  1529509800        93
# 502              Airai          80           TL  1529511496        90
#
#      Latitude  Longitude  Max_temp  Wind_speed
# 493     51.31     119.61     13.59        1.21
# 494     62.45    -114.38     23.00        1.50
# 495    -14.02     -39.89     22.49        2.91
# 496      7.01      39.97     15.89        1.36
# 497     60.73      77.60     15.00        6.00
# 498     42.27     118.96     13.64        1.36
# 499      2.82     -60.67     26.00        2.60
# 500    -42.88     147.33      7.00        3.60
# 501     70.03      20.97      9.00        5.10
# 502     -8.93     125.41     19.99        0.76

# %%
weather_df.to_csv("weatherdata.csv",index=False,header=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
x_axis=weather_df["Latitude"]
y_axis_maxtemp=weather_df["Max_temp"]
y_axis_humidity=weather_df["Humidity"]
y_axis_cloudiness = weather_df["Cloudiness"]
y_axis_Windspeed = weather_df["Wind_speed"]

# %%
weather_df.loc[weather_df["Max_temp"] >= 35]
# Out:
#           City  Cloudiness Country_code        Date  Humidity  Latitude  \
# 15       Mecca           0           SA  1529506800        32     21.43
# 95    Umm Lajj           8           SA  1529511430        48     25.02
# 137  Iranshahr           0           IR  1529506800        10     27.21
# 168       Jalu          20           LY  1529511440        27     29.03
# 179       Dori          68           BF  1529511441        32     14.03
# 181   Oussouye          20           SN  1529506800        58     12.49
# 194   Tessalit           0           ML  1529511444        10     20.20
# 222      Kidal           0           ML  1529511448        10     18.44
# 307      Zabol           0           IR  1529506800         9     31.03
# 320  Abu Kamal           0           SY  1529511465        13     34.45
# 338        Gao           0           ML  1529511468        13     16.28
# 366      Cabra           0           ES  1529510400        22     37.47
# 437      Adrar           0           DZ  1529506800        12     27.87
#
#      Longitude  Max_temp  Wind_speed
# 15       39.83     41.00        5.10
# 95       37.27     35.39        8.91
# 137      60.69     43.00        6.20
# 168      21.55     35.29        3.76
# 179      -0.03     38.04        5.36
# 181     -16.54     36.00        3.10
# 194       1.01     43.49        5.91
# 222       1.41     44.49        5.91
# 307      61.49     40.00        4.10
# 320      40.92     36.64        4.81
# 338      -0.04     44.09        3.06
# 366      -4.43     36.00        1.00
# 437      -0.29     43.00        2.60

# %%
#weather_df_sortedbytemp = weather_df.sort("Max_temp",axis=1,ascending=False,inplace=False)
#weather_df_sortedbytemp.head(10)

# %%
#Plot Latitude vs maximum temp(C)
sns.regplot(x_axis, y_axis_maxtemp, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label="Latitude vs Max temperature(C)", 
            color=None,marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title("Latitude vs Max temperature(C) Date: 06/20/2018 ")
plt.xlim(-65,85)
plt.ylim(-10,50)
plt.ylabel("Maximum Temp in C")
plt.savefig("latvsMaxtemp.png")

# %%
#Plot of latitude vs Humidity
sns.regplot(x_axis, y_axis_humidity, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, 
            marker='o', scatter_kws=None, line_kws=None, ax=None)

# %%
#Plot of latitude vs Cloudiness
sns.regplot(x_axis, y_axis_cloudiness, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, 
            marker='o', scatter_kws=None, line_kws=None, ax=None)

# %%
#Latitude vs windspeed
sns.regplot(x_axis, y_axis_Windspeed, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, 
            marker='o', scatter_kws=None, line_kws=None, ax=None)
